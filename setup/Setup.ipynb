# %% [markdown]
# <a href="https://colab.research.google.com/github/Data-Science-and-Data-Analytics-Courses/MITx---Machine-Learning-with-Python-From-Linear-Models-to-Deep-Learning-Jun-11-2019/blob/master/setup/Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup
#
# ---

# %% [markdown]
# ## Dependencies

# %% [markdown]
# ## Libraries

# %%
from scipy import special as spec

# %% [markdown]
# ## Globals

# %%
# Drive
CONFILE_GIT_REL = "GitHub/config.json" # relative path to GitHub configuration file
AUTHFILE_GIT_REL = "GitHub/login.json" # relative path to GitHub authentication file
AUTHFILE_UM_REL = "UniMelb/login.json" # relative path to UniMelb authentication file
